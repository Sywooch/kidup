# %%
import pandas as pd
import urllib.parse as urlparse
import glob

df = pd.read_hdf('D:/studyportals/tracking/hdfstore2.h5')

df.head()
# Out:
# C:\Users\simon\Anaconda3\lib\site-packages\tables\leaf.py:386: PerformanceWarning: The Leaf ``/tracking/_i_table/refr/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)
#    cd cookie            cs         ds            dtm              duid   e  \
# 0  24      1  windows-1252  1349x2992  1451309411775  952cefa234e0adfe  pv
# 0  32      1    ISO-8859-1   375x5853  1451309438482  060261284cb986be  pv
# 0  24      1  windows-1252  1825x3965  1451309444136  cc225f316b4085ac  pv
# 0  24      1  windows-1252  1349x3174  1451309448622  a69806978480e537  pv
# 0  24      1  windows-1252  1349x3019  1451309692206  0b14a4b8933c21d4  pv
#
#                                     eid f_ag f_dir    ...    se_pr se_va  \
# 0  5f3ef788-2049-43fc-9327-2fde9b23369e    0     0    ...      NaN   NaN
# 0  50462f76-dc4f-4b5c-88ff-9e9d8bd8d3a1  NaN   NaN    ...      NaN   NaN
# 0  b9e043bf-2342-4368-a58d-bae3b0215adb    0     0    ...      NaN   NaN
# 0  1713b3be-67ad-43ad-92b5-e51ac6b97e98    0     0    ...      NaN   NaN
# 0  43cc157c-fd20-4d26-9cb9-a0831df98005    0     0    ...      NaN   NaN
#
#                                     sid tna        tv                   tz  \
# 0  d3e02a67-b71f-40a2-b1e3-3adeda937697  cf  js-2.5.1         Asia/Jakarta
# 0  8347dc0b-b2c5-493c-bb2a-7ace39bd2115  cf  js-2.5.1  Africa/Johannesburg
# 0  7f89b6fa-07db-43f8-900a-c900feeb6a6d  cf  js-2.5.1         Africa/Lagos
# 0  754ad5bb-54c9-42dc-aa4e-581be07a4f87  cf  js-2.5.1  America/Los_Angeles
# 0  0faa1ebc-9458-4d3f-ae98-24dba267c896  cf  js-2.5.1        Asia/Shanghai
#
#                                              uid  \
# 0  6f84c668-9c50-41f5-8a85-1fb1aba5a465 HTTP/1.1
# 0  0aa7896e-882d-480c-a889-070377aeae00 HTTP/1.1
# 0  455f1ae7-8134-4805-a996-4e7b5a22ebb8 HTTP/1.1
# 0  11e1402b-c083-4a20-8acd-858cb426431c HTTP/1.1
# 0  c8badd32-139b-445c-a2c8-4d368516f913 HTTP/1.1
#
#                                                  url vid        vp
# 0  http://www.bachelorsportal.eu/universities/sch...   1  1366x623
# 0  http://www.bachelorsportal.eu/studies/31759/bu...   1   375x628
# 0                     http://www.bachelorsportal.eu/   4  1842x544
# 0  http://www.bachelorsportal.eu/studies/42606/bu...   1  1366x667
# 0  http://www.bachelorsportal.eu/studies/34132/oc...   1  1366x667
#
# [5 rows x 35 columns]

# %%
import pandas as pd

starting = {'Col_1':[5,2,4,7,2,4],
            'Col_2':[7,8,2,1,5,6],
            'Col_3':[10,4,2,1,8,2],
            'Name':['HG','TY','CS','YU','PO','XW'],
            'Col_4':[5,6,7,1,1,4],
            'Col_5':[9,9,2,1,5,2],
            'Col_6':[7,8,2,1,7,8],}

df = pd.DataFrame(starting)

print(df.index)

df = df.set_index('Name')

print(df.index)

print(df.head())
# Out:
# Int64Index([0, 1, 2, 3, 4, 5], dtype='int64')
# Index(['HG', 'TY', 'CS', 'YU', 'PO', 'XW'], dtype='object', name='Name')
#       Col_1  Col_2  Col_3  Col_4  Col_5  Col_6
# Name
# HG        5      7     10      5      9      7
# TY        2      8      4      6      9      8
# CS        4      2      2      7      2      2
# YU        7      1      1      1      1      1
# PO        2      5      8      1      5      7
